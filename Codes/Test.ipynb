# %% [markdown]
# Import the necessary sourcecodes

# %%
import sys
from pathlib import Path

# Notebook cwd is ".../LV network/Codes"
cwd = Path.cwd()

# Helpers live in the sibling "sourcecode" folder under Codes:
helpers_dir = (cwd / "sourcecode").resolve()
print("Adding to sys.path:", helpers_dir)
sys.path.insert(0, str(helpers_dir))

# Now import the module by name (filename without .py)
from Network_Plotting import plot_pf_with_transformer_capacity

# Test it
import pandapower as pp, pandapower.networks as pn
net = pn.create_cigre_network_lv(); pp.runpp(net, numba=False)
plot_pf_with_transformer_capacity(net, filename="test.png")
# Out:
# Adding to sys.path: E:\GitHubProjects\LV network\Codes\sourcecode
# Plot saved to figures\test.png

# %% [markdown]
# # Pandapower CIGRE LV Network Example
# 1. See what is in the network

# %%
import pandapower.networks as pn
import pandas as pd

# 1) Load the network
net = pn.create_cigre_network_lv()

# 2) Optional: show all table names
print("Available tables:", [k for k in net.keys() if isinstance(net[k], pd.DataFrame)])

# 3) Define which ones you want to inspect
tables = [
    ("Buses",      net.bus),
    ("External Grids", net.ext_grid),
    ("Lines",      net.line),
    ("Transformers",   net.trafo),
    ("Loads",      net.load),
    ("Switches",   net.switch),
    ("Impedances", net.impedance),
    ("Shunts",     net.shunt),
    ("Generators", net.gen),
    ("Static Gens",net.sgen),
]

# 4) Print each in turn
for title, df in tables:
    print(f"\n=== {title} ===")
    display(df)
# Out:
# Available tables: ['bus', 'bus_dc', 'load', 'sgen', 'motor', 'asymmetric_load', 'asymmetric_sgen', 'storage', 'gen', 'switch', 'shunt', 'svc', 'ssc', 'vsc', 'ext_grid', 'line', 'line_dc', 'trafo', 'trafo3w', 'impedance', 'tcsc', 'dcline', 'ward', 'xward', 'measurement', 'pwl_cost', 'poly_cost', 'controller', 'group', '_empty_res_bus', '_empty_res_bus_dc', '_empty_res_ext_grid', '_empty_res_line', '_empty_res_line_dc', '_empty_res_trafo', '_empty_res_load', '_empty_res_asymmetric_load', '_empty_res_asymmetric_sgen', '_empty_res_motor', '_empty_res_sgen', '_empty_res_shunt', '_empty_res_svc', '_empty_res_ssc', '_empty_res_vsc', '_empty_res_switch', '_empty_res_impedance', '_empty_res_tcsc', '_empty_res_dcline', '_empty_res_ward', '_empty_res_xward', '_empty_res_trafo_3ph', '_empty_res_trafo3w', '_empty_res_bus_3ph', '_empty_res_ext_grid_3ph', '_empty_res_line_3ph', '_empty_res_asymmetric_load_3ph', '_empty_res_asymmetric_sgen_3ph', '_empty_res_storage', '_empty_res_storage_3ph', '_empty_res_gen', '_empty_res_protection', '_empty_res_load_3ph', '_empty_res_sgen_3ph', 'res_bus', 'res_bus_dc', 'res_line', 'res_line_dc', 'res_trafo', 'res_trafo3w', 'res_impedance', 'res_ext_grid', 'res_load', 'res_motor', 'res_sgen', 'res_storage', 'res_shunt', 'res_gen', 'res_ward', 'res_xward', 'res_dcline', 'res_asymmetric_load', 'res_asymmetric_sgen', 'res_switch', 'res_tcsc', 'res_svc', 'res_ssc', 'res_vsc', 'res_bus_est', 'res_line_est', 'res_trafo_est', 'res_trafo3w_est', 'res_impedance_est', 'res_switch_est', 'res_shunt_est', 'res_bus_sc', 'res_line_sc', 'res_trafo_sc', 'res_trafo3w_sc', 'res_ext_grid_sc', 'res_gen_sc', 'res_sgen_sc', 'res_switch_sc', 'res_bus_3ph', 'res_line_3ph', 'res_trafo_3ph', 'res_ext_grid_3ph', 'res_shunt_3ph', 'res_load_3ph', 'res_sgen_3ph', 'res_storage_3ph', 'res_asymmetric_load_3ph', 'res_asymmetric_sgen_3ph']
#
# === Buses ===
#        name  vn_kv type      zone  in_service  \
# 0     Bus 0   20.0    b  CIGRE_LV        True
# 1    Bus R0   20.0    b  CIGRE_LV        True
# 2    Bus R1    0.4    b  CIGRE_LV        True
# 3    Bus R2    0.4    m  CIGRE_LV        True
# 4    Bus R3    0.4    m  CIGRE_LV        True
# 5    Bus R4    0.4    m  CIGRE_LV        True
# 6    Bus R5    0.4    m  CIGRE_LV        True
# 7    Bus R6    0.4    m  CIGRE_LV        True
# 8    Bus R7    0.4    m  CIGRE_LV        True
# 9    Bus R8    0.4    m  CIGRE_LV        True
# 10   Bus R9    0.4    m  CIGRE_LV        True
# 11  Bus R10    0.4    m  CIGRE_LV        True
# 12  Bus R11    0.4    m  CIGRE_LV        True
# 13  Bus R12    0.4    m  CIGRE_LV        True
# 14  Bus R13    0.4    m  CIGRE_LV        True
# 15  Bus R14    0.4    m  CIGRE_LV        True
# 16  Bus R15    0.4    m  CIGRE_LV        True
# 17  Bus R16    0.4    m  CIGRE_LV        True
# 18  Bus R17    0.4    m  CIGRE_LV        True
# 19  Bus R18    0.4    m  CIGRE_LV        True
# 20   Bus I0   20.0    b  CIGRE_LV        True
# 21   Bus I1    0.4    b  CIGRE_LV        True
# 22   Bus I2    0.4    m  CIGRE_LV        True
# 23   Bus C0   20.0    b  CIGRE_LV        True
# 24   Bus C1    0.4    b  CIGRE_LV        True
# 25   Bus C2    0.4    m  CIGRE_LV        True
# 26   Bus C3    0.4    m  CIGRE_LV        True
# 27   Bus C4    0.4    m  CIGRE_LV        True
# 28   Bus C5    0.4    m  CIGRE_LV        True
# 29   Bus C6    0.4    m  CIGRE_LV        True
# 30   Bus C7    0.4    m  CIGRE_LV        True
# 31   Bus C8    0.4    m  CIGRE_LV        True
# 32   Bus C9    0.4    m  CIGRE_LV        True
# 33  Bus C10    0.4    m  CIGRE_LV        True
# 34  Bus C11    0.4    m  CIGRE_LV        True
# 35  Bus C12    0.4    m  CIGRE_LV        True
# 36  Bus C13    0.4    m  CIGRE_LV        True
# 37  Bus C14    0.4    m  CIGRE_LV        True
# 38  Bus C15    0.4    m  CIGRE_LV        True
# 39  Bus C16    0.4    m  CIGRE_LV        True
# 40  Bus C17    0.4    m  CIGRE_LV        True
# 41  Bus C18    0.4    m  CIGRE_LV        True
# 42  Bus C19    0.4    m  CIGRE_LV        True
# 43  Bus C20    0.4    m  CIGRE_LV        True
#
#                                                   geo
# 0          {"type":"Point", "coordinates":[0.2, 1.0]}
# 1          {"type":"Point", "coordinates":[0.2, 1.0]}
# 2   {"type":"Point", "coordinates":[-1.4583333333,...
# 3   {"type":"Point", "coordinates":[-1.4583333333,...
# 4   {"type":"Point", "coordinates":[-1.4583333333,...
# 5   {"type":"Point", "coordinates":[-1.9583333333,...
# 6   {"type":"Point", "coordinates":[-2.7083333333,...
# 7   {"type":"Point", "coordinates":[-2.7083333333,...
# 8   {"type":"Point", "coordinates":[-3.2083333333,...
# 9   {"type":"Point", "coordinates":[-3.2083333333,...
# 10  {"type":"Point", "coordinates":[-3.2083333333,...
# 11  {"type":"Point", "coordinates":[-3.7083333333,...
# 12  {"type":"Point", "coordinates":[-0.9583333333,...
# 13  {"type":"Point", "coordinates":[-1.2083333333,...
# 14  {"type":"Point", "coordinates":[-1.2083333333,...
# 15  {"type":"Point", "coordinates":[-1.2083333333,...
# 16  {"type":"Point", "coordinates":[-1.2083333333,...
# 17  {"type":"Point", "coordinates":[-2.2083333333,...
# 18  {"type":"Point", "coordinates":[-2.7083333333,...
# 19  {"type":"Point", "coordinates":[-3.7083333333,...
# 20         {"type":"Point", "coordinates":[0.2, 1.0]}
# 21         {"type":"Point", "coordinates":[0.2, 2.0]}
# 22         {"type":"Point", "coordinates":[0.2, 3.0]}
# 23         {"type":"Point", "coordinates":[0.2, 1.0]}
# 24  {"type":"Point", "coordinates":[1.9166666667, ...
# 25  {"type":"Point", "coordinates":[1.9166666667, ...
# 26  {"type":"Point", "coordinates":[1.9166666667, ...
# 27  {"type":"Point", "coordinates":[0.5416666667, ...
# 28  {"type":"Point", "coordinates":[0.5416666667, ...
# 29  {"type":"Point", "coordinates":[-0.2083333333,...
# 30  {"type":"Point", "coordinates":[-0.2083333333,...
# 31  {"type":"Point", "coordinates":[-0.2083333333,...
# 32  {"type":"Point", "coordinates":[-0.7083333333,...
# 33  {"type":"Point", "coordinates":[3.2916666667, ...
# 34  {"type":"Point", "coordinates":[2.7916666667, ...
# 35  {"type":"Point", "coordinates":[2.2916666667, ...
# 36  {"type":"Point", "coordinates":[3.2916666667, ...
# 37  {"type":"Point", "coordinates":[3.7916666667, ...
# 38  {"type":"Point", "coordinates":[1.2916666667, ...
# 39  {"type":"Point", "coordinates":[0.7916666667, ...
# 40  {"type":"Point", "coordinates":[1.7916666667, ...
# 41  {"type":"Point", "coordinates":[0.7916666667, ...
# 42  {"type":"Point", "coordinates":[0.2916666667, ...
# 43  {"type":"Point", "coordinates":[-0.7083333333,...
# === External Grids ===
#    name  bus  vm_pu  va_degree  slack_weight  in_service  s_sc_max_mva  \
# 0  None    0    1.0        0.0           1.0        True         100.0
#
#    s_sc_min_mva  rx_min  rx_max
# 0         100.0     1.0     1.0
# === Lines ===
#             name std_type  from_bus  to_bus  length_km  r_ohm_per_km  \
# 0     Line R1-R2      UG1         2       3      0.035        0.1620
# 1     Line R2-R3      UG1         3       4      0.035        0.1620
# 2     Line R3-R4      UG1         4       5      0.035        0.1620
# 3     Line R4-R5      UG1         5       6      0.035        0.1620
# 4     Line R5-R6      UG1         6       7      0.035        0.1620
# 5     Line R6-R7      UG1         7       8      0.035        0.1620
# 6     Line R7-R8      UG1         8       9      0.035        0.1620
# 7     Line R8-R9      UG1         9      10      0.035        0.1620
# 8    Line R9-R10      UG1        10      11      0.035        0.1620
# 9    Line R3-R11      UG3         4      12      0.030        0.8220
# 10   Line R4-R12      UG3         5      13      0.035        0.8220
# 11  Line R12-R13      UG3        13      14      0.035        0.8220
# 12  Line R13-R14      UG3        14      15      0.035        0.8220
# 13  Line R14-R15      UG3        15      16      0.030        0.8220
# 14   Line R6-R16      UG3         7      17      0.030        0.8220
# 15   Line R9-R17      UG3        10      18      0.030        0.8220
# 16  Line R10-R18      UG3        11      19      0.030        0.8220
# 17    Line I1-I2      UG2        21      22      0.200        0.2647
# 18    Line C1-C2      OH1        24      25      0.030        0.4917
# 19    Line C2-C3      OH1        25      26      0.030        0.4917
# 20    Line C3-C4      OH1        26      27      0.030        0.4917
# 21    Line C4-C5      OH1        27      28      0.030        0.4917
# 22    Line C5-C6      OH1        28      29      0.030        0.4917
# 23    Line C6-C7      OH1        29      30      0.030        0.4917
# 24    Line C7-C8      OH1        30      31      0.030        0.4917
# 25    Line C8-C9      OH1        31      32      0.030        0.4917
# 26   Line C3-C10      OH2        26      33      0.030        1.3207
# 27  Line C10-C11      OH2        33      34      0.030        1.3207
# 28  Line C11-C12      OH3        34      35      0.030        2.0167
# 29  Line C11-C13      OH3        34      36      0.030        2.0167
# 30  Line C10-C14      OH3        33      37      0.030        2.0167
# 31   Line C5-C15      OH2        28      38      0.030        1.3207
# 32  Line C15-C16      OH2        38      39      0.030        1.3207
# 33  Line C15-C17      OH3        38      40      0.030        2.0167
# 34  Line C16-C18      OH3        39      41      0.030        2.0167
# 35   Line C8-C19      OH3        31      42      0.030        2.0167
# 36   Line C9-C20      OH3        32      43      0.030        2.0167
#
#     x_ohm_per_km  c_nf_per_km  g_us_per_km  max_i_ka   df  parallel type  \
# 0         0.0832          0.0          0.0       1.0  1.0         1   cs
# 1         0.0832          0.0          0.0       1.0  1.0         1   cs
# 2         0.0832          0.0          0.0       1.0  1.0         1   cs
# 3         0.0832          0.0          0.0       1.0  1.0         1   cs
# 4         0.0832          0.0          0.0       1.0  1.0         1   cs
# 5         0.0832          0.0          0.0       1.0  1.0         1   cs
# 6         0.0832          0.0          0.0       1.0  1.0         1   cs
# 7         0.0832          0.0          0.0       1.0  1.0         1   cs
# 8         0.0832          0.0          0.0       1.0  1.0         1   cs
# 9         0.0847          0.0          0.0       1.0  1.0         1   cs
# 10        0.0847          0.0          0.0       1.0  1.0         1   cs
# 11        0.0847          0.0          0.0       1.0  1.0         1   cs
# 12        0.0847          0.0          0.0       1.0  1.0         1   cs
# 13        0.0847          0.0          0.0       1.0  1.0         1   cs
# 14        0.0847          0.0          0.0       1.0  1.0         1   cs
# 15        0.0847          0.0          0.0       1.0  1.0         1   cs
# 16        0.0847          0.0          0.0       1.0  1.0         1   cs
# 17        0.0823          0.0          0.0       1.0  1.0         1   cs
# 18        0.2847          0.0          0.0       1.0  1.0         1   ol
# 19        0.2847          0.0          0.0       1.0  1.0         1   ol
# 20        0.2847          0.0          0.0       1.0  1.0         1   ol
# 21        0.2847          0.0          0.0       1.0  1.0         1   ol
# 22        0.2847          0.0          0.0       1.0  1.0         1   ol
# 23        0.2847          0.0          0.0       1.0  1.0         1   ol
# 24        0.2847          0.0          0.0       1.0  1.0         1   ol
# 25        0.2847          0.0          0.0       1.0  1.0         1   ol
# 26        0.3210          0.0          0.0       1.0  1.0         1   ol
# 27        0.3210          0.0          0.0       1.0  1.0         1   ol
# 28        0.3343          0.0          0.0       1.0  1.0         1   ol
# 29        0.3343          0.0          0.0       1.0  1.0         1   ol
# 30        0.3343          0.0          0.0       1.0  1.0         1   ol
# 31        0.3210          0.0          0.0       1.0  1.0         1   ol
# 32        0.3210          0.0          0.0       1.0  1.0         1   ol
# 33        0.3343          0.0          0.0       1.0  1.0         1   ol
# 34        0.3343          0.0          0.0       1.0  1.0         1   ol
# 35        0.3343          0.0          0.0       1.0  1.0         1   ol
# 36        0.3343          0.0          0.0       1.0  1.0         1   ol
#
#     in_service  geo
# 0         True  NaN
# 1         True  NaN
# 2         True  NaN
# 3         True  NaN
# 4         True  NaN
# 5         True  NaN
# 6         True  NaN
# 7         True  NaN
# 8         True  NaN
# 9         True  NaN
# 10        True  NaN
# 11        True  NaN
# 12        True  NaN
# 13        True  NaN
# 14        True  NaN
# 15        True  NaN
# 16        True  NaN
# 17        True  NaN
# 18        True  NaN
# 19        True  NaN
# 20        True  NaN
# 21        True  NaN
# 22        True  NaN
# 23        True  NaN
# 24        True  NaN
# 25        True  NaN
# 26        True  NaN
# 27        True  NaN
# 28        True  NaN
# 29        True  NaN
# 30        True  NaN
# 31        True  NaN
# 32        True  NaN
# 33        True  NaN
# 34        True  NaN
# 35        True  NaN
# 36        True  NaN
# === Transformers ===
#           name std_type  hv_bus  lv_bus  sn_mva  vn_hv_kv  vn_lv_kv  \
# 0  Trafo R0-R1     None       1       2    0.50      20.0       0.4
# 1  Trafo I0-I1     None      20      21    0.15      20.0       0.4
# 2  Trafo C0-C1     None      23      24    0.30      20.0       0.4
#
#    vk_percent  vkr_percent  pfe_kw  ...  tap_max  tap_step_percent  \
# 0    4.123106     1.000000     0.0  ...      NaN               NaN
# 1    4.126896     1.003125     0.0  ...      NaN               NaN
# 2    4.115529     0.993750     0.0  ...      NaN               NaN
#
#   tap_step_degree  tap_pos  tap_changer_type  id_characteristic_table  \
# 0             NaN      0.0               NaN                     <NA>
# 1             NaN      0.0               NaN                     <NA>
# 2             NaN      0.0               NaN                     <NA>
#
#    tap_dependency_table  parallel   df in_service
# 0                 False         1  1.0       True
# 1                 False         1  1.0       True
# 2                 False         1  1.0       True
#
# [3 rows x 25 columns]
# === Loads ===
#         name  bus     p_mw    q_mvar  const_z_percent  const_i_percent  \
# 0    Load R1    2  0.19000  0.062450              0.0              0.0
# 1   Load R11   12  0.01425  0.004684              0.0              0.0
# 2   Load R15   16  0.04940  0.016237              0.0              0.0
# 3   Load R16   17  0.05225  0.017174              0.0              0.0
# 4   Load R17   18  0.03325  0.010929              0.0              0.0
# 5   Load R18   19  0.04465  0.014676              0.0              0.0
# 6    Load I2   22  0.08500  0.052678              0.0              0.0
# 7    Load C1   24  0.10800  0.052307              0.0              0.0
# 8   Load C12   35  0.01800  0.008718              0.0              0.0
# 9   Load C13   36  0.01800  0.008718              0.0              0.0
# 10  Load C14   37  0.02250  0.010897              0.0              0.0
# 11  Load C17   40  0.02250  0.010897              0.0              0.0
# 12  Load C18   41  0.00720  0.003487              0.0              0.0
# 13  Load C19   42  0.01440  0.006974              0.0              0.0
# 14  Load C20   43  0.00720  0.003487              0.0              0.0
#
#     sn_mva  scaling  in_service type
# 0      NaN      1.0        True  wye
# 1      NaN      1.0        True  wye
# 2      NaN      1.0        True  wye
# 3      NaN      1.0        True  wye
# 4      NaN      1.0        True  wye
# 5      NaN      1.0        True  wye
# 6      NaN      1.0        True  wye
# 7      NaN      1.0        True  wye
# 8      NaN      1.0        True  wye
# 9      NaN      1.0        True  wye
# 10     NaN      1.0        True  wye
# 11     NaN      1.0        True  wye
# 12     NaN      1.0        True  wye
# 13     NaN      1.0        True  wye
# 14     NaN      1.0        True  wye
# === Switches ===
#    bus  element et type  closed name  z_ohm  in_ka
# 0    0        1  b   CB    True   S1    0.0    NaN
# 1    0       20  b   CB    True   S2    0.0    NaN
# 2    0       23  b   CB    True   S3    0.0    NaN
# === Impedances ===
# Empty DataFrame
# Columns: [name, from_bus, to_bus, rft_pu, xft_pu, rtf_pu, xtf_pu, gf_pu, bf_pu, gt_pu, bt_pu, sn_mva, in_service]
# Index: []
# === Shunts ===
# Empty DataFrame
# Columns: [bus, name, q_mvar, p_mw, vn_kv, step, max_step, id_characteristic_table, step_dependency_table, in_service]
# Index: []
# === Generators ===
# Empty DataFrame
# Columns: [name, bus, p_mw, vm_pu, sn_mva, min_q_mvar, max_q_mvar, scaling, slack, in_service, slack_weight, type]
# Index: []
# === Static Gens ===
# Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, scaling, in_service, type, current_source]
# Index: []

# %%
print(net.load['p_mw'].sum() * 1000, "kW total load")
df = net.load.copy()
mask = df["name"].str.contains("Load R", case=True, na=False)

# 3) Select those rows
df_load_r = df[mask]

# 4) Inspect or save
print(df_load_r['p_mw'].sum() * 1000, "kW total Load R")
print(df_load_r['p_mw'] * 1000/3, "Number of homes at each Load R Node")
# Optionally write out to a new file:
df_load_r.to_csv("loads_with_Load_R.csv", index=False)
# Out:
# 686.5999999999999 kW total load
# 383.80000000000007 kW total Load R
# 0    63.333333
# 1     4.750000
# 2    16.466667
# 3    17.416667
# 4    11.083333
# 5    14.883333
# Name: p_mw, dtype: float64 Number of homes at each Load R Node

# %% [markdown]
# 2. This is the function for plotting the results from power flow, according to 3 metrics:
#
#     a. Bus voltage (pu)
#
#     b. Line real power (MW) from the "from" bus
#
#     c. Transformer sizing, which is 4/3 of the maximum transformer load (MVA)

# %%
import pandapower.networks as pn
import pandapower as pp

# 1) build & solve
net = pn.create_cigre_network_lv()
pp.runpp(net, numba=False)

# 2) call the plotter
plot_pf_with_transformer_capacity(net)
# Out:
# Plot saved to pf_plot.png

# %%
print("=== net.trafo ===")
display(net.trafo)

# 3) View the transformer results (loadings, flows, losses…)
print("\n=== net.res_trafo ===")
display(net.res_trafo)
# Out:
# === net.trafo ===
#           name std_type  hv_bus  lv_bus  sn_mva  vn_hv_kv  vn_lv_kv  \
# 0  Trafo R0-R1     None       1       2    0.50      20.0       0.4
# 1  Trafo I0-I1     None      20      21    0.15      20.0       0.4
# 2  Trafo C0-C1     None      23      24    0.30      20.0       0.4
#
#    vk_percent  vkr_percent  pfe_kw  ...  tap_max  tap_step_percent  \
# 0    4.123106     1.000000     0.0  ...      NaN               NaN
# 1    4.126896     1.003125     0.0  ...      NaN               NaN
# 2    4.115529     0.993750     0.0  ...      NaN               NaN
#
#   tap_step_degree  tap_pos  tap_changer_type  id_characteristic_table  \
# 0             NaN      0.0               NaN                     <NA>
# 1             NaN      0.0               NaN                     <NA>
# 2             NaN      0.0               NaN                     <NA>
#
#    tap_dependency_table  parallel   df in_service
# 0                 False         1  1.0       True
# 1                 False         1  1.0       True
# 2                 False         1  1.0       True
#
# [3 rows x 25 columns]
# === net.res_trafo ===
#     p_hv_mw  q_hv_mvar   p_lv_mw  q_lv_mvar     pl_mw   ql_mvar   i_hv_ka  \
# 0  0.398174   0.144641 -0.394585  -0.130284  0.003589  0.014357  0.012229
# 1  0.089469   0.056832 -0.088717  -0.053834  0.000751  0.002998  0.003060
# 2  0.227286   0.117287 -0.225119  -0.108578  0.002167  0.008708  0.007383
#
#     i_lv_ka  vm_hv_pu  va_hv_degree  vm_lv_pu  va_lv_degree  loading_percent
# 0  0.611460       1.0           0.0  0.980893    -31.691920        84.726382
# 1  0.152988       1.0           0.0  0.979056    -31.174975        70.662014
# 2  0.369163       1.0           0.0  0.977213    -31.546446        85.254638

# %% [markdown]
# # Hybrid Heat Pump Operation Optimization

# %%
import gurobipy as gp
from gurobipy import GRB
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def optimize_hhp_operation(
    R1: float,
    C1: float,
    g: float,
    tariff: pd.DataFrame,
    Tout: np.ndarray,
    S: np.ndarray,
    dt: float,
    T0: float,
    T_setpoint: np.ndarray,
    tol: float | np.ndarray,
    COP: float,
    etaB: float,
    Qhp_max: float,
    Qbo_max: float,
) -> pd.DataFrame:
    """
    Hybrid‐HP dispatch with comfort constraints.
    Returns: DataFrame with ['Q_hp','Q_bo','Tin','T_set','T_low','T_high']
    """

    T = len(tariff)
    beta = dt * R1 / (C1 * R1 + dt)

    m = gp.Model("hhp_dispatch")
    m.Params.OutputFlag = 0

    # decision vars
    Q_hp = m.addVars(T, lb=0, ub=Qhp_max, name="Q_hp")
    Q_bo = m.addVars(T, lb=0, ub=Qbo_max, name="Q_bo")
    Tin  = m.addVars(T, lb=-GRB.INFINITY, name="Tin")

    # objective
    m.setObjective(
        gp.quicksum(
            (Q_hp[t]/COP)*tariff['elec_price'].iat[t] +
            (Q_bo[t]/etaB)*tariff['gas_price'].iat[t]
            for t in range(T)
        ),
        GRB.MINIMIZE
    )

    # initial condition
    m.addConstr(Tin[0] == T0, name="init_temp")

    # dynamics
    for t in range(1, T):
        m.addConstr(
            Tin[t] == Tin[t-1]
                      + beta * (
                          (Tout[t-1] - Tin[t-1]) / R1
                        + Q_hp[t-1]
                        + Q_bo[t-1]
                        + g * S[t-1]
                      ),
            name=f"dyn_{t}"
        )

    # build comfort bands
    tol_arr = tol if np.ndim(tol) > 0 else np.full(T, tol)
    T_low = np.where(T_setpoint >= 19.0, T_setpoint - tol_arr, 15.0)
    T_high = np.where(T_setpoint >= 19.0, T_setpoint + tol_arr, np.nan)  # NaN if no upper bound

    for t in range(T):
        m.addConstr(Tin[t] >= T_low[t], name=f"tmin_{t}")
        if not np.isnan(T_high[t]):
            m.addConstr(Tin[t] <= T_high[t], name=f"tmax_{t}")

    m.optimize()

    if m.Status != GRB.OPTIMAL:
        raise RuntimeError(f"Gurobi did not find an optimal solution. Status: {m.Status}")

    Qhp_res = np.array([Q_hp[t].X for t in range(T)])
    Qbo_res = np.array([Q_bo[t].X for t in range(T)])
    Tin_res = np.array([Tin[t].X for t in range(T)])

    return pd.DataFrame({
        'Q_hp': Qhp_res,
        'Q_bo': Qbo_res,
        'Tin': Tin_res,
        'T_set': T_setpoint,
        'T_low': T_low,
        'T_high': T_high
    }, index=tariff.index)

# %% [markdown]
# Now we generate the ToU tariff profile

# %%
# --- Parameters ---
start_date = pd.to_datetime("2022-01-03")
n_days = 25  # change to however many days you want
step = "30min"

# --- Helper to apply daily tariff pattern ---
def daily_tariff(day):
    times = pd.date_range(day, day + pd.Timedelta("1D") - pd.Timedelta(step), freq=step)

    elec = pd.Series(15.0, index=times) # default electricity price 15.0
    gas  = pd.Series(5.0, index=times) # default gas price 5.0

    cosy_periods = [
        (day + pd.Timedelta("02:00:00"), day + pd.Timedelta("05:00:00")),
        (day + pd.Timedelta("13:00:00"), day + pd.Timedelta("17:00:00")),
        (day + pd.Timedelta("21:00:00"), day + pd.Timedelta("24:00:00")),
    ]
    high_periods = [(day + pd.Timedelta("17:00:00"), day + pd.Timedelta("20:00:00"))]

    for start, end in cosy_periods:
        elec[start:end] = 5.0
    for start, end in high_periods:
        elec[start:end] = 30.0

    return pd.DataFrame({"elec_price": elec, "gas_price": gas})

# --- Build multi-day tariff ---
tariff_list = [daily_tariff(start_date + pd.Timedelta(days=i)) for i in range(n_days)]
tariff = pd.concat(tariff_list)

# --- Check output ---
print(tariff.head(10))
print(tariff.tail(10))
# Out:
#                      elec_price  gas_price
# 2022-01-03 00:00:00        15.0        5.0
# 2022-01-03 00:30:00        15.0        5.0
# 2022-01-03 01:00:00        15.0        5.0
# 2022-01-03 01:30:00        15.0        5.0
# 2022-01-03 02:00:00         5.0        5.0
# 2022-01-03 02:30:00         5.0        5.0
# 2022-01-03 03:00:00         5.0        5.0
# 2022-01-03 03:30:00         5.0        5.0
# 2022-01-03 04:00:00         5.0        5.0
# 2022-01-03 04:30:00         5.0        5.0
#                      elec_price  gas_price
# 2022-01-27 19:00:00        30.0        5.0
# 2022-01-27 19:30:00        30.0        5.0
# 2022-01-27 20:00:00        30.0        5.0
# 2022-01-27 20:30:00        15.0        5.0
# 2022-01-27 21:00:00         5.0        5.0
# 2022-01-27 21:30:00         5.0        5.0
# 2022-01-27 22:00:00         5.0        5.0
# 2022-01-27 22:30:00         5.0        5.0
# 2022-01-27 23:00:00         5.0        5.0
# 2022-01-27 23:30:00         5.0        5.0

# %% [markdown]
# Now get the data and run the optimization

# %%
# load data
# tariff = pd.read_csv("tariff.csv", index_col=0, parse_dates=True)

df     = pd.read_csv(r"E:\Python projects\RC model\Test data\Property_ID=EOH0031_2022_01.csv", parse_dates=["Timestamp"], index_col="Timestamp")
df = df.loc[tariff.index[0]:tariff.index[-1]]  # align with tariff index
dt     = df.index.to_series().diff().median().total_seconds()

Tout = df["External_Air_Temperature"].values
S    = df["GHI"].values

# define a daily setpoint schedule plus ±0.5°C tolerance
# e.g. 20°C from midnight–06:00, 22°C from 06:00–22:00, back to 20°C
hours = tariff.index.hour
T_set = np.where((hours>=6)&(hours<10)|(hours>=17)&(hours<21), 25.0, 15.0)
print(len(T_set))
tol   = 1

# other parameters
R1, C1, g = 1/200, 3e7, 10.0
T0    = 20
COP   = 3.5
etaB  = 0.9
Qhp_max = 4e3
Qbo_max = 24e3

results = optimize_hhp_operation(
    R1, C1, g, tariff, Tout, S, dt, T0,
    T_setpoint=T_set, tol=tol,
    COP=COP, etaB=etaB,
    Qhp_max=Qhp_max, Qbo_max=Qbo_max
)

print(results)
# Out:
# 1200
#                        Q_hp  Q_bo        Tin  T_set  T_low  T_high
# 2022-01-03 00:00:00  4000.0   0.0  20.000000   15.0   15.0     NaN
# 2022-01-03 00:30:00  4000.0   0.0  20.104625   15.0   15.0     NaN
# 2022-01-03 01:00:00  4000.0   0.0  20.208601   15.0   15.0     NaN
# 2022-01-03 01:30:00  4000.0   0.0  20.307788   15.0   15.0     NaN
# 2022-01-03 02:00:00  4000.0   0.0  20.397498   15.0   15.0     NaN
# ...                     ...   ...        ...    ...    ...     ...
# 2022-01-27 21:30:00     0.0   0.0  23.560040   15.0   15.0     NaN
# 2022-01-27 22:00:00     0.0   0.0  23.342712   15.0   15.0     NaN
# 2022-01-27 22:30:00     0.0   0.0  23.128055   15.0   15.0     NaN
# 2022-01-27 23:00:00     0.0   0.0  22.916948   15.0   15.0     NaN
# 2022-01-27 23:30:00     0.0   0.0  22.709877   15.0   15.0     NaN
#
# [1200 rows x 6 columns]

# %% [markdown]
# Generating a case for cooling down process

# %% [markdown]
# Plot the results

# %%
from typing import Optional

def plot_hhp_results_components(
    Tin: np.ndarray,
    Q_hp: np.ndarray,
    Q_bo: np.ndarray,
    T_set: np.ndarray,
    T_low: np.ndarray,
    T_high: np.ndarray,
    index: pd.DatetimeIndex,
    tariff: pd.DataFrame,
    df: pd.DataFrame,
    include_measured: bool = True,
    title_prefix: str = "Hybrid Heat Pump Dispatch"
):
    """
    Modular plotting function using raw result arrays instead of DataFrame.

    Parameters
    ----------
    Tin, Q_hp, Q_bo : np.ndarray
        Arrays of results: indoor temperature, HP/boiler thermal output
    T_set, T_low, T_high : np.ndarray
        Setpoint and comfort bounds
    index : pd.DatetimeIndex
        Shared time index
    tariff : pd.DataFrame
        DataFrame with 'elec_price' and 'gas_price'
    df : pd.DataFrame
        Monitoring data including 'External_Air_Temperature', 'GHI', 'Internal_Air_Temperature'
    include_measured : bool
        Whether to plot measured indoor temperature from df
    title_prefix : str
        Title prefix for the plot
    """
    fig, axs = plt.subplots(6, 1, figsize=(12, 14), sharex=True)

    # 1. Tariff prices
    axs[0].plot(tariff.index, tariff["elec_price"], label="Electricity (p/kWh)", color='blue')
    axs[0].plot(tariff.index, tariff["gas_price"], label="Gas (p/kWh)", color='orange')
    axs[0].set_ylabel("Tariff (p/kWh)")
    axs[0].legend()
    axs[0].grid(True)

    # 2. Thermal energy delivered
    axs[1].plot(index, Q_hp / 1000, label="HP Heat (kW)", color='green')
    axs[1].plot(index, Q_bo / 1000, label="Boiler Heat (kW)", color='red')
    axs[1].set_ylabel("Heat Output (kW)")
    axs[1].legend()
    axs[1].grid(True)

    # 3. Indoor air temperature + comfort band
    axs[2].plot(index, T_set, label="Setpoint", color="blue")
    axs[2].fill_between(index, T_low, T_high, color="lightblue", alpha=0.3, label="Comfort Band")
    axs[2].plot(index, Tin, label="Modelled Indoor T", color='purple')
    axs[2].set_ylabel("Indoor Temp (°C)")
    axs[2].legend()
    axs[2].grid(True)

    # 4. Outdoor temperature and GHI
    axs[3].plot(df.index, df["External_Air_Temperature"], label="Outdoor Temp (°C)", color='black')
    axs[3].plot(df.index, df["GHI"] / 100, label="GHI (x0.01 W/m²)", color='gold', linestyle=':')
    axs[3].set_ylabel("Outdoor / GHI")
    axs[3].legend()
    axs[3].grid(True)

    # 5. Total thermal power
    axs[4].plot(index, (Q_hp + Q_bo) / 1000, label="Total Heat (kW)", color='teal')
    axs[4].set_ylabel("Total Heat (kW)")
    axs[4].legend()
    axs[4].grid(True)

    # 6. Measured indoor temperature
    if include_measured and "Internal_Air_Temperature" in df.columns:
        axs[5].plot(df.index, df["Internal_Air_Temperature"], label="Measured Indoor T", color='purple')
        axs[5].set_ylabel("Measured T (°C)")
        axs[5].legend()
        axs[5].grid(True)

    plt.xlabel("Time")
    plt.suptitle(title_prefix, y=1.02)
    plt.tight_layout()
    plt.show()
    
plot_hhp_results_components(
    Tin=results["Tin"].values,
    Q_hp=results["Q_hp"].values,
    Q_bo=results["Q_bo"].values,
    T_set=results["T_set"].values,
    T_low=results["T_low"].values,
    T_high=results["T_high"].values,
    index=results.index,
    tariff=tariff,
    df=df,
    title_prefix="Cooling Scenario"
)

# %%
# Simulate the RC dynamics for indoor temperature
def simulate_rc_dynamics(
    R1: float,
    C1: float,
    g: float,
    Tout: np.ndarray,
    S: np.ndarray,
    Q_hp: np.ndarray,
    Q_bo: np.ndarray,
    dt: float,
    T0: float
) -> np.ndarray:
    """
    Simulate indoor temperature dynamics using grey-box RC model.

    Parameters
    ----------
    R1, C1, g     : Thermal resistance [K/W], capacitance [J/K], solar gain factor [W/(m²·K)]
    Tout, S      : Outdoor temp [°C] and solar radiation [W/m²]
    Q_hp, Q_bo   : Heat input from HP and boiler [W]
    dt           : Time step [s]
    T0           : Initial indoor temperature [°C]

    Returns
    -------
    Tin : np.ndarray
        Simulated indoor temperature [°C] over time
    """
    T = len(Tout)
    Tin = np.zeros(T)
    Tin[0] = T0
    beta = dt * R1 / (C1 * R1 + dt)

    for t in range(1, T):
        Tin[t] = Tin[t-1] + beta * (
            (Tout[t-1] - Tin[t-1]) / R1 +
            Q_hp[t-1] +
            Q_bo[t-1] +
            g * S[t-1]
        )
    return Tin

Tout_cooldown = np.zeros(len(Tout))  # Assume 0 degree outdoor temperature change for cooling
Qhp_cooldown = np.zeros(len(Tout))  # No HP in cooling scenario
Qbo_cooldown = np.zeros(len(Tout))  # No boiler in cooling scenario
T0_cooldown = 22  # Initial indoor temperature for cooling


Tin_cooldown = simulate_rc_dynamics(
    R1=R1, C1=C1, g=g,
    Tout=Tout_cooldown, S=S,
    Q_hp=Qhp_cooldown,  # No HP in cooling scenario
    Q_bo=Qbo_cooldown,  # No boiler in cooling scenario
    dt=dt, T0=T0_cooldown)

plot_hhp_results_components(
    Tin=Tin_cooldown,
    Q_hp=Qhp_cooldown,
    Q_bo=Qbo_cooldown,
    T_set=results["T_set"].values,
    T_low=results["T_low"].values,
    T_high=results["T_high"].values,
    index=results.index,
    tariff=tariff,
    df=df,
    title_prefix="Cooling Scenario"
)

# %%
print(Tin_cooldown)
# Out:
# [22.         21.73913043 21.48135418 21.22663457 20.97493535 20.7262207
#  20.48045523 20.23760399 19.9976324  19.76050632 19.52619202 19.29465614
#  19.06586575 18.8397883  18.6163916  18.39564387 18.17751371 17.96197006
#  17.74898228 17.53852004 17.33351782 17.13391089 16.93904238 16.74885611
#  16.56418588 16.38496628 16.20757538 16.03199148 15.86175048 15.69678901
#  15.53141206 15.36562457 15.19468831 15.01866434 14.84265251 14.66665267
#  14.4927398  14.32088913 14.15107621 13.98327689 13.81746728 13.6536238
#  13.49172312 13.33174221 13.17365831 13.01744893 12.86309182 12.71056504
#  12.55984688 12.41091589 12.26375088 12.11833091 11.97463529 11.83264356
#  11.69233554 11.55369124 11.41669095 11.28131517 11.14754463 11.01536031
#  10.88474339 10.75567528 10.62813763 10.50211229 10.37758131 10.25452699
#  10.13322825 10.01366428  9.90707932  9.81331949  9.74023665  9.68758562
#   9.64919528  9.62489652  9.60385032  9.5860181   9.56068982  9.52795437
#   9.47870985  9.41315203  9.32939924  9.22766723  9.12269489  9.01452064
#   8.90762909  8.80200503  8.69763343  8.59449944  8.49258838  8.39188575
#   8.29237722  8.19404864  8.09688601  8.0008755   7.90600346  7.81225638
#   7.71962093  7.62808393  7.53763234  7.4482533   7.35993409  7.27266214
#   7.18642504  7.10121052  7.01700644  6.93380083  6.85158185  6.77033779
#   6.69005711  6.61072837  6.53234028  6.4548817   6.3783416   6.3027091
#   6.22826986  6.15500974  6.09447603  6.04651781  6.01898993  6.01165013
#   6.01803373  6.03797799  6.06065019  6.08601797  6.10219167  6.10928031
#   6.0996841   6.07360089  6.02944752  5.96743826  5.90142121  5.83144388
#   5.76229632  5.6939687   5.62645128  5.55973447  5.49380877  5.42866479
#   5.36429327  5.30068505  5.23783108  5.17572241  5.1143502   5.05370574
#   4.99378037  4.93456558  4.87605295  4.81823414  4.76110093  4.70464519
#   4.64885888  4.59373407  4.53926292  4.48543766  4.43225066  4.37969432
#   4.32776119  4.27644386  4.22573504  4.17562751  4.12611414  4.07718789
#   4.02884179  3.98106896  3.93741992  3.89784577  3.85992665  3.82364294
#   3.78897523  3.75590438  3.72530077  3.69713515  3.67078572  3.64623095
#   3.62226378  3.59887726  3.5692463   3.53344496  3.49480727  3.45336687
#   3.41241786  3.3719544   3.33197076  3.29246122  3.25342018  3.21484207
#   3.17672142  3.13905278  3.10183081  3.06505021  3.02870574  2.99279224
#   2.95730458  2.92223773  2.88758669  2.85334653  2.81951238  2.78607943
#   2.75304291  2.72039813  2.68814045  2.65626527  2.62476805  2.59364432
#   2.56288964  2.53249965  2.50247001  2.47279645  2.44347475  2.41450074
#   2.38616674  2.35846516  2.33968889  2.32973211  2.33352975  2.35091873
#   2.38322009  2.430257    2.47970059  2.53152233  2.5794687   2.62358567
#   2.65265383  2.66685161  2.66339092  2.64248114  2.61648334  2.58545785
#   2.55480025  2.52450617  2.49457132  2.46499142  2.43576227  2.40687972
#   2.37833964  2.35013798  2.32227074  2.29473393  2.26752364  2.24063601
#   2.21406721  2.18781344  2.16187099  2.13623616  2.1109053   2.0858748
#   2.0611411   2.0367007   2.01255009  1.98868586  1.96510461  1.94180297
#   1.91877764  1.89602534  1.87354282  1.8513269   1.82937441  1.80768222
#   1.78624725  1.76506646  1.74591547  1.72877023  1.72309311  1.72874813
#   1.74619381  1.77529032  1.80196672  1.8262517   1.84728429  1.86510305
#   1.88063543  1.89390853  1.89398076  1.88100865  1.86344729  1.84135107
#   1.81951687  1.79794157  1.77662211  1.75555544  1.73473858  1.71416856
#   1.69384245  1.67375736  1.65391043  1.63429885  1.61491981  1.59577056
#   1.57684838  1.55815058  1.53967448  1.52141747  1.50337695  1.48555034
#   1.46793512  1.45052878  1.43332883  1.41633284  1.39953838  1.38294306
#   1.36654453  1.35034044  1.3343285   1.31850642  1.30287196  1.28742288
#   1.27245344  1.25795795  1.2531205   1.25782658  1.27907765  1.31667752
#   1.36005684  1.40914707  1.45735877  1.50470234  1.53992326  1.56316528
#   1.5799064   1.59022372  1.58974675  1.57860351  1.56373865  1.54519629
#   1.52687381  1.50876858  1.49087805  1.47319965  1.45573088  1.43846925
#   1.4214123   1.40455761  1.38790278  1.37144543  1.35518323  1.33911387
#   1.32323505  1.30754451  1.29204003  1.2767194   1.26158043  1.24662098
#   1.23183892  1.21723213  1.20279855  1.18853611  1.1744428   1.1605166
#   1.14675554  1.13315764  1.11972099  1.10644367  1.09332378  1.08035947
#   1.06754888  1.0548902   1.04534605  1.03887949  1.0351576   1.03414783
#   1.0364109   1.041908    1.04852569  1.05625068  1.06536629  1.07585602
#   1.0844427   1.09114892  1.09066099  1.08306422  1.07288954  1.06016753
#   1.04759637  1.03517428  1.02289949  1.01077025  0.99878483  0.98694153
#   0.97523867  0.96367457  0.9522476   0.94095613  0.92979854  0.91877326
#   0.90787872  0.89711336  0.88647565  0.87596408  0.86557716  0.8553134
#   0.84517134  0.83514955  0.82524659  0.81546105  0.80579155  0.79623671
#   0.78679517  0.77746559  0.76824663  0.75913698  0.75013536  0.74124047
#   0.7327475   0.72465168  0.72999178  0.74860848  0.78597676  0.84187427
#   0.90867022  0.9862354   1.06436304  1.14304648  1.20893921  1.2621929
#   1.29999298  1.32252271  1.33144537  1.3269223   1.31682045  1.30120598
#   1.28577666  1.2705303   1.25546472  1.24057779  1.22586738  1.2113314
#   1.19696779  1.1827745   1.1687495   1.15489081  1.14119645  1.12766448
#   1.11429296  1.10108     1.08802372  1.07512225  1.06237377  1.04977645
#   1.03732851  1.02502817  1.01287369  1.00086333  0.98899538  0.97726816
#   0.96568     0.95422925  0.94291428  0.93173348  0.92068526  0.90976804
#   0.89927672  0.88920624  0.88577692  0.88891     0.90000988  0.9189821
#   0.94247243  0.9704273   1.00071868  1.03331885  1.06434669  1.09382084
#   1.11494154  1.12780785  1.13133186  1.12562437  1.1161308   1.10289605
#   1.08981823  1.07689549  1.06412597  1.05150788  1.03903941  1.02671878
#   1.01454425  1.00251408  0.99062656  0.97888     0.96727273  0.95580309]

# %% [markdown]
# #Get the baseload from Pullinger et al SERL archetype paper

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# ----------------------------
# Step 1: Load digitized points
# ----------------------------
csv_path = r"E:\GitHubProjects\LV network\Default Dataset.csv"  # 🔁 Update this
df = pd.read_csv(csv_path, header=None, names=["x", "y"])

# Sort just in case
df = df.sort_values("x")

x_raw = df["x"].values*24  # Convert to hours if needed
y_raw = df["y"].values*276 # Convert to kWh/m² if needed

# ----------------------------
# Step 2: Create interpolator
# ----------------------------
f_interp = interp1d(
    x_raw, y_raw,
    kind="linear",
    bounds_error=False,
    fill_value="extrapolate"
)

# ----------------------------
# Step 3: Query at half-hourly intervals
# ----------------------------
x_query = np.arange(0, 24, 0.5)  # or change to 24.5 for hourly scale
y_query = f_interp(x_query)

# ----------------------------
# Step 4: Save or print results
# ----------------------------
result_df = pd.DataFrame({"x": x_query, "y": y_query})
print(result_df)
result_df.to_csv('E:\GitHubProjects\LV network\Data_for_CIGRE_Network\Baseload_from_SERL.csv', index=False)
# ----------------------------
# Step 5: Optional: Plot for verification
# ----------------------------
plt.plot(x_raw, y_raw, 'o-', label='Original Points')
plt.plot(x_query, y_query, 's--', color='red', label='Half-hourly Interpolated')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Piecewise Linear Interpolation")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#        x           y
# 0    0.0  276.000000
# 1    0.5  293.416043
# 2    1.0  287.023396
# 3    1.5  283.236847
# 4    2.0  274.809729
# 5    2.5  266.382612
# 6    3.0  257.955494
# 7    3.5  249.528377
# 8    4.0  241.849899
# 9    4.5  234.342984
# 10   5.0  240.577540
# 11   5.5  255.312299
# 12   6.0  301.976471
# 13   6.5  355.675936
# 14   7.0  409.375401
# 15   7.5  433.533088
# 16   8.0  434.327662
# 17   8.5  428.390374
# 18   9.0  422.453087
# 19   9.5  409.295455
# 20  10.0  381.677005
# 21  10.5  356.438503
# 22  11.0  343.662433
# 23  11.5  338.704211
# 24  12.0  343.893048
# 25  12.5  351.226604
# 26  13.0  348.271658
# 27  13.5  335.169213
# 28  14.0  324.115508
# 29  14.5  322.376671
# 30  15.0  328.100535
# 31  15.5  344.778610
# 32  16.0  379.151515
# 33  16.5  435.269875
# 34  17.0  491.388235
# 35  17.5  540.536898
# 36  18.0  562.233155
# 37  18.5  552.860963
# 38  19.0  533.026025
# 39  19.5  513.191087
# 40  20.0  493.527819
# 41  20.5  474.536921
# 42  21.0  455.546023
# 43  21.5  436.442131
# 44  22.0  410.784568
# 45  22.5  383.694118
# 46  23.0  345.959358
# 47  23.5  309.208556
